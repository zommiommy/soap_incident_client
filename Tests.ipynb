# %%
import zeep
from zeep import xsd
from zeep import Client
from lxml import etree as ET

# %%
client = Client("./wsdls/sviluppo.wsdl")

# %%
def dict_to_obj(**kwargs):
    seq =  xsd.Element("ins", xsd.Sequence([
        xsd.Element(key, xsd.String())
        for key in kwargs.keys()
    ]))
    return xsd.AnyObject(seq, xsd.ComplexType(seq)(**kwargs))

node = client.create_message(client.service, "ProcessOperation", 
            identId="identId",
            password="password",
            prozess="prozess",
            version=1.0,
            processData=dict_to_obj(en="a", it="b")
)
tree = ET.ElementTree(node)
print(ET.tostring(tree, pretty_print=True).decode())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-146-876c77ecdf9f> in <module>
#      11             prozess="prozess",
#      12             version=1.0,
# ---> 13             processData=dict_to_obj(en="a", it="b")
#      14 )
#      15 tree = ET.ElementTree(node)
#
# <ipython-input-146-876c77ecdf9f> in dict_to_obj(**kwargs)
#       4         for key in kwargs.keys()
#       5     ]))
# ----> 6     return xsd.AnyObject(seq, xsd.ComplexType(seq)(**kwargs))
#       7
#       8 node = client.create_message(client.service, "ProcessOperation",
#
# ~/.local/lib/python3.8/site-packages/zeep/xsd/types/complex.py in __call__(self, *args, **kwargs)
#      47         if self._array_type:
#      48             return self._array_class(*args, **kwargs)
# ---> 49         return self._value_class(*args, **kwargs)
#      50
#      51     @property
#
# ~/.local/lib/python3.8/site-packages/zeep/xsd/valueobjects.py in __init__(self, *args, **kwargs)
#      93
#      94         # Set elements
# ---> 95         items = _process_signature(self._xsd_type, args, kwargs)
#      96         for key, value in items.items():
#      97             values[key] = value
#
# ~/.local/lib/python3.8/site-packages/zeep/xsd/valueobjects.py in _process_signature(xsd_type, args, kwargs)
#     233                 xsd_type.qname or "ComplexType",
#     234                 next(iter(available_kwargs)),
# --> 235                 xsd_type.signature(standalone=False),
#     236             )
#     237         )
#
# ~/.local/lib/python3.8/site-packages/zeep/xsd/types/complex.py in signature(self, schema, standalone)
#     473         parts = []
#     474         for name, element in self.elements_nested:
# --> 475             part = element.signature(schema, standalone=False)
#     476             parts.append(part)
#     477
#
# ~/.local/lib/python3.8/site-packages/zeep/xsd/elements/element.py in signature(self, schema, standalone)
#     305         from zeep.xsd import ComplexType
#     306
# --> 307         if self.type.is_global or (not standalone and self.is_global):
#     308             value = self.type.get_prefixed_name(schema)
#     309         else:
#
# AttributeError: 'Sequence' object has no attribute 'is_global'
